# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("zomato.csv", encoding=('ISO-8859-1'))

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.drop(columns =['Longitude','Latitude','Restaurant ID','Address','Locality Verbose'],axis=1,inplace=True)
df
# Out:
#                Restaurant Name  Country Code              City  \
# 0             Le Petit Souffle           162       Makati City
# 1             Izakaya Kikufuji           162       Makati City
# 2       Heat - Edsa Shangri-La           162  Mandaluyong City
# 3                         Ooma           162  Mandaluyong City
# 4                  Sambo Kojin           162  Mandaluyong City
# ...                        ...           ...               ...
# 9546              NamlÛ± Gurme           208         ÛÁstanbul
# 9547             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548                     Huqqa           208         ÛÁstanbul
# 9549              Aôôk Kahve           208         ÛÁstanbul
# 9550  Walter's Coffee Roastery           208         ÛÁstanbul
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant Name', 'Country Code', 'City', 'Locality', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.shape
# Out:
# (9551, 16)

# %%
df.describe()
# Out:
#        Country Code  Average Cost for two  Price range  Aggregate rating  \
# count   9551.000000           9551.000000  9551.000000       9551.000000
# mean      18.365616           1199.210763     1.804837          2.666370
# std       56.750546          16121.183073     0.905609          1.516378
# min        1.000000              0.000000     1.000000          0.000000
# 25%        1.000000            250.000000     1.000000          2.500000
# 50%        1.000000            400.000000     2.000000          3.200000
# 75%        1.000000            700.000000     2.000000          3.700000
# max      216.000000         800000.000000     4.000000          4.900000
#
#               Votes
# count   9551.000000
# mean     156.909748
# std      430.169145
# min        0.000000
# 25%        5.000000
# 50%       31.000000
# 75%      131.000000
# max    10934.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),annot=True,linewidths=1)
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Restaurant Name         0
# Country Code            0
# City                    0
# Locality                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Restaurant Name', 'Country Code', 'City', 'Locality', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.rename({'Has Table booking':'Accepts_Table_Booking','Rating color':'Rating_Schema','Rating text':'Rating','Average Cost for two':'Avg_Cost','Has Online delivery':'Online_Delivery','Aggregate rating':'Aggregate_Rating'},axis=1,inplace=True)
df
# Out:
#                Restaurant Name  Country Code              City  \
# 0             Le Petit Souffle           162       Makati City
# 1             Izakaya Kikufuji           162       Makati City
# 2       Heat - Edsa Shangri-La           162  Mandaluyong City
# 3                         Ooma           162  Mandaluyong City
# 4                  Sambo Kojin           162  Mandaluyong City
# ...                        ...           ...               ...
# 9546              NamlÛ± Gurme           208         ÛÁstanbul
# 9547             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548                     Huqqa           208         ÛÁstanbul
# 9549              Aôôk Kahve           208         ÛÁstanbul
# 9550  Walter's Coffee Roastery           208         ÛÁstanbul
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.head()
# Out:
#           Restaurant Name  Country Code              City  \
# 0        Le Petit Souffle           162       Makati City
# 1        Izakaya Kikufuji           162       Makati City
# 2  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3                    Ooma           162  Mandaluyong City
# 4             Sambo Kojin           162  Mandaluyong City
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                            Cuisines  Avg_Cost          Currency  \
# 0        French, Japanese, Desserts      1100  Botswana Pula(P)
# 1                          Japanese      1200  Botswana Pula(P)
# 2  Seafood, Asian, Filipino, Indian      4000  Botswana Pula(P)
# 3                   Japanese, Sushi      1500  Botswana Pula(P)
# ...

# %%
subset_df = df[['Aggregate_Rating','Rating_Schema','Rating','Votes']]
subset_df
# Out:
#       Aggregate_Rating Rating_Schema     Rating  Votes
# 0                  4.8    Dark Green  Excellent    314
# 1                  4.5    Dark Green  Excellent    591
# 2                  4.4         Green  Very Good    270
# 3                  4.9    Dark Green  Excellent    365
# 4                  4.8    Dark Green  Excellent    229
# ...                ...           ...        ...    ...
# 9546               4.1         Green  Very Good    788
# 9547               4.2         Green  Very Good   1034
# 9548               3.7        Yellow       Good    661
# 9549               4.0         Green  Very Good    901
# 9550               4.0         Green  Very Good    591
#
# [9551 rows x 4 columns]

# %%
subset_df['Rating_Schema'].value_counts()
# Out:
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating_Schema, dtype: int64

# %%
subset_df['Rating'].value_counts()
# Out:
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating, dtype: int64

# %%
df['Accepts_Table_Booking'].value_counts()
# Out:
# No     8393
# Yes    1158
# Name: Accepts_Table_Booking, dtype: int64

# %%
result_rating = subset_df.groupby('Rating_Schema')['Aggregate_Rating','Rating'].aggregate(['min','max'])
result_rating
# Out:
#               Aggregate_Rating          Rating
#                            min  max        min        max
# Rating_Schema
# Dark Green                 4.5  4.9  Excellent  Excellent
# Green                      4.0  4.4  Very Good  Very Good
# Orange                     2.5  3.4    Average    Average
# Red                        1.8  2.4       Poor       Poor
# White                      0.0  0.0  Not rated  Not rated
# Yellow                     3.5  3.9       Good       Good

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df,x='Aggregate_Rating',color="Green",width=0.3)
# Out:
# <AxesSubplot:xlabel='Aggregate_Rating'>

# %%
df1 = pd.read_excel('Country-Code.xlsx')
df1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df2 = pd.merge(df,df1,on='Country Code',how='left')
df2
# Out:
#                Restaurant Name  Country Code              City  \
# 0             Le Petit Souffle           162       Makati City
# 1             Izakaya Kikufuji           162       Makati City
# 2       Heat - Edsa Shangri-La           162  Mandaluyong City
# 3                         Ooma           162  Mandaluyong City
# 4                  Sambo Kojin           162  Mandaluyong City
# ...                        ...           ...               ...
# 9546              NamlÛ± Gurme           208         ÛÁstanbul
# 9547             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548                     Huqqa           208         ÛÁstanbul
# 9549              Aôôk Kahve           208         ÛÁstanbul
# 9550  Walter's Coffee Roastery           208         ÛÁstanbul
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df2.head()
# Out:
#           Restaurant Name  Country Code              City  \
# 0        Le Petit Souffle           162       Makati City
# 1        Izakaya Kikufuji           162       Makati City
# 2  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3                    Ooma           162  Mandaluyong City
# 4             Sambo Kojin           162  Mandaluyong City
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                            Cuisines  Avg_Cost          Currency  \
# 0        French, Japanese, Desserts      1100  Botswana Pula(P)
# 1                          Japanese      1200  Botswana Pula(P)
# 2  Seafood, Asian, Filipino, Indian      4000  Botswana Pula(P)
# 3                   Japanese, Sushi      1500  Botswana Pula(P)
# ...

# %%
currency_df = df2.loc[:,['Country Code','Currency']]

# %%
currency_df.value_counts()
# Out:
# Country Code  Currency
# 1             Indian Rupees(Rs.)        8652
# 216           Dollar($)                  434
# 215           Pounds(£)                  80
# 30            Brazilian Real(R$)          60
# 189           Rand(R)                     60
# 214           Emirati Diram(AED)          60
# 148           NewZealand($)               40
# 208           Turkish Lira(TL)            34
# 14            Dollar($)                   24
# 162           Botswana Pula(P)            22
# 94            Indonesian Rupiah(IDR)      21
# 166           Qatari Rial(QR)             20
# 184           Dollar($)                   20
# 191           Sri Lankan Rupee(LKR)       20
# 37            Dollar($)                    4
# dtype: int64

# %%
df2['Online_Delivery'].value_counts()
# Out:
# No     7100
# Yes    2451
# Name: Online_Delivery, dtype: int64

# %%
perc_penetration = df2.Country.value_counts() *100/ len(df2['Country'])
perc_penetration
# Out:
# India             90.587373
# United States      4.544027
# United Kingdom     0.837609
# Brazil             0.628206
# UAE                0.628206
# South Africa       0.628206
# New Zealand        0.418804
# Turkey             0.355984
# Australia          0.251283
# Phillipines        0.230342
# Indonesia          0.219872
# Singapore          0.209402
# Qatar              0.209402
# Sri Lanka          0.209402
# Canada             0.041880
# Name: Country, dtype: float64

# %%
country_names = df2.Country.value_counts().index
country_names
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object')

# %%
country_values = df2.Country.value_counts().values
country_values
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %%
plt.pie(country_values[:3],labels=country_names[:3],autopct='%1.3f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d159c5ad60>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.392%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.735%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.873%')])

# %%
df2.groupby(['Country','Online_Delivery']).size().reset_index()
# Out:
#            Country Online_Delivery     0
# 0        Australia              No    24
# 1           Brazil              No    60
# 2           Canada              No     4
# 3            India              No  6229
# 4            India             Yes  2423
# 5        Indonesia              No    21
# 6      New Zealand              No    40
# 7      Phillipines              No    22
# 8            Qatar              No    20
# 9        Singapore              No    20
# 10    South Africa              No    60
# 11       Sri Lanka              No    20
# 12          Turkey              No    34
# 13             UAE              No    32
# 14             UAE             Yes    28
# 15  United Kingdom              No    80
# 16   United States              No   434

# %%
df2[df2['Online_Delivery']=='Yes'].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
df2[df2['Online_Delivery']=='No'].Country.value_counts()
# Out:
# India             6229
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# New Zealand         40
# Turkey              34
# UAE                 32
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
df2.loc[df2['Online_Delivery']=='Yes',['Country','Currency']].value_counts()
# Out:
# Country  Currency
# India    Indian Rupees(Rs.)    2423
# UAE      Emirati Diram(AED)      28
# dtype: int64

# %%
Indian_cities = df2[df2['Country']=='India']

# %%
Indian_cities
# Out:
#                             Restaurant Name  Country Code   City  \
# 624                              Jahanpanah             1   Agra
# 625                     Rangrezz Restaurant             1   Agra
# 626                 Time2Eat - Mama Chicken             1   Agra
# 627   Chokho Jeeman Marwari Jain Bhojanalya             1   Agra
# 628                          Pinch Of Spice             1   Agra
# ...                                     ...           ...    ...
# 9271                               D Cabana             1  Vizag
# 9272                               Kaloreez             1  Vizag
# 9273                                Plot 17             1  Vizag
# 9274                       Vista - The Park             1  Vizag
# 9275               Flying Spaghetti Monster             1  Vizag
#
#                    Locality  \
# 624              Agra Cantt
# 625              Agra Cantt
# 626              Agra Cantt
# 627             Civil Lines
# 628             Civil Lines
# ...

# %%
Indian_cities.shape
# Out:
# (8652, 17)

# %%
City_count = Indian_cities['City'].value_counts()
City_count
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Lucknow           21
# Bhubaneshwar      21
# Amritsar          21
# Pune              20
# Puducherry        20
# Patna             20
# Ludhiana          20
# Ranchi            20
# Surat             20
# Vadodara          20
# Nashik            20
# Nagpur            20
# Mysore            20
# Mumbai            20
# Varanasi          20
# Mangalore         20
# Agra              20
# Kochi             20
# Kolkata           20
# Dehradun          20
# Allahabad         20
# Aurangabad        20
# Bangalore         20
# Bhopal            20
# Chennai           20
# Coimbatore        20
# Goa               20
# Indore            20
# Jaipur            20
# Kanpur            20
# Vizag             20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Panchkula          1
# Mohali             1
# ...

# %%
City_count[:3]
# Out:
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# Name: City, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(df2['Rating_Schema'],palette=['green','lightgreen','yellow','orange','gray','red'])
plt.title('Rating_Schema_Zomato')
plt.show()

# %%
result_rating
# Out:
#               Aggregate_Rating          Rating
#                            min  max        min        max
# Rating_Schema
# Dark Green                 4.5  4.9  Excellent  Excellent
# Green                      4.0  4.4  Very Good  Very Good
# Orange                     2.5  3.4    Average    Average
# Red                        1.8  2.4       Poor       Poor
# White                      0.0  0.0  Not rated  Not rated
# Yellow                     3.5  3.9       Good       Good

# %%
plt.figure(figsize=(8,6))
sns.countplot(df2['Accepts_Table_Booking'],palette=['orange','red'])
plt.title('Accepts_Table_Booking_Zomato')
plt.show()

# %% [markdown]
# # Average Cost for two

# %%
df2.groupby('Country')['Avg_Cost'].mean().sort_values(ascending=False).round(0)
# Out:
# Country
# Indonesia         281190.0
# Sri Lanka           2375.0
# Phillipines         1607.0
# India                623.0
# South Africa         420.0
# Qatar                224.0
# UAE                  166.0
# Singapore            156.0
# Brazil               135.0
# Turkey                85.0
# New Zealand           70.0
# United Kingdom        48.0
# Canada                36.0
# United States         26.0
# Australia             24.0
# Name: Avg_Cost, dtype: float64

# %% [markdown]
# # Price range

# %%
Indian_cities.groupby('City')['Avg_Cost'].mean().sort_values(ascending=False)[-3:]
# Out:
# City
# Varanasi     505.000000
# Amritsar     480.952381
# Faridabad    447.609562
# Name: Avg_Cost, dtype: float64

# %%
df2.columns
# Out:
# Index(['Restaurant Name', 'Country Code', 'City', 'Locality', 'Cuisines',
#        'Avg_Cost', 'Currency', 'Accepts_Table_Booking', 'Online_Delivery',
#        'Is delivering now', 'Switch to order menu', 'Price range',
#        'Aggregate_Rating', 'Rating_Schema', 'Rating', 'Votes', 'Country'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))
sns.countplot(df2['Price range'],palette='rocket_r')
plt.title('Price range_Zomato')
plt.show()
